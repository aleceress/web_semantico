# %%
from mulearn import FuzzyInductor
from mulearn.kernel import PrecomputedKernel, GaussianKernel
from mulearn.fuzzifier import *
from mulearn.optimization import GurobiSolver
import csv
import numpy as np
from sklearn.model_selection import KFold, RandomizedSearchCV, GridSearchCV
import random
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

def get_kernel_and_solver(gram):
    eigvals = np.linalg.eigvals(gram)
    assert(sum([abs(e.imag) for e in eigvals]) < 1e-4)
    abs_neg_eigvals = [-l.real for l in eigvals if l < 0]
    adjustment = max(abs_neg_eigvals) if abs_neg_eigvals else 0

    kernel = PrecomputedKernel(gram)
    solver = GurobiSolver(adjustment=adjustment) if adjustment else GurobiSolver()
    return kernel, solver

def get_dataset(filename):
    with open(filename) as data_file:
        data = np.array(list(csv.reader(data_file)))

    n = len(data) - 1

    # ## Extract data names, membership values and Gram matrix

    names = np.array(data[0])[1:n+1]
    mu = np.array([float(row[0]) for row in data[1:n+1]])
    gram = np.array([[float(k.replace('NA', '0')) for k in row[1:n+1]]
                     for row in data[1:n+1]])

    assert(len(names.shape) == 1)
    assert(len(mu.shape) == 1)
    assert(len(gram.shape) == 2)

    assert(names.shape[0] == gram.shape[0] == gram.shape[1] == mu.shape[0])

    X = np.arange(n)

    return X, gram, mu

data_file_name = 'data/data-tettamanzi-complete.csv'
X, gram, mu = get_dataset(data_file_name)
k,s = get_kernel_and_solver(gram)

cs = [0.005, 0.007, 0.01, 0.03, 0.05, 0.07, 0.1, 0.3, 0.5,0.7, 1, 10, 100]

fuzzifiers = [LinearFuzzifier(), ExponentialFuzzifier(), CrispFuzzifier(),
              QuantileConstantPiecewiseFuzzifier(),
              QuantileLinearPiecewiseFuzzifier()]
mean_scores = []
std_scores = []

X = X.reshape(len(X), -1)

# %%
for fuzzifier in fuzzifiers:
    test_scores = []

    for i in range(10):
        X_trainval, X_test, mu_trainval, mu_test = \
                train_test_split(X, mu, test_size=0.1)

        
        X_train, X_validation, mu_train, mu_validation = \
                train_test_split(X_trainval, mu_trainval, train_size=8/9)
            
        rmse_min = np.inf
        best_param = None
        
        for c in cs:
            try:
                fi = FuzzyInductor(c=c, fuzzifier=fuzzifier, k=k, solver=s)
                fi.fit(X_train, mu_train)
                predictions = fi.predict(X_validation)
                rmse = mean_squared_error(predictions, mu_validation,
                                          squared=False)
                if  rmse < rmse_min:
                    best_param = c
                    rmse_min = rmse
            except ValueError as e:
                print(e)
                continue
                  
        print(f"in experiment {i} best c is {best_param}")
        
        try:
            fi = FuzzyInductor(c=best_param, fuzzifier=fuzzifier, k=k, solver=s)
            fi.fit(X_trainval, mu_trainval)
            predictions = fi.predict(X_test)
            rmse = mean_squared_error(predictions, mu_test, squared=False)
            print(f"in experiment {i} test rmse is {rmse}")
            test_scores.append(rmse)
        except (ValueError,TypeError):
            test_scores.append(np.nan)

    mean_scores.append(np.nanmean(test_scores))
    std_scores.append(np.nanstd(test_scores))
# Out:
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 0 best c is None
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 1 best c is None
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 2 best c is None
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 3 best c is None
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 4 best c is None
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 5 best c is None
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 6 best c is None
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 7 best c is None
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 8 best c is None
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 9 best c is None
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:41: RuntimeWarning: Mean of empty slice
# D:\anaconda\lib\site-packages\numpy\lib\nanfunctions.py:1666: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# in experiment 0 best c is 0.005
# in experiment 0 test rmse is 0.31988205304628403
# in experiment 1 best c is 0.005
# in experiment 1 test rmse is 0.2874190710316315
# in experiment 2 best c is 0.005
# in experiment 2 test rmse is 0.33178726563871247
# in experiment 3 best c is 0.005
# in experiment 3 test rmse is 0.3329338481599702
# in experiment 4 best c is 0.005
# in experiment 4 test rmse is 0.3234655139219625
# in experiment 5 best c is 0.005
# in experiment 5 test rmse is 0.37006033679610895
# in experiment 6 best c is 0.005
# in experiment 6 test rmse is 0.30217020653222615
# in experiment 7 best c is 0.005
# in experiment 7 test rmse is 0.33289682287015815
# in experiment 8 best c is 0.005
# in experiment 8 test rmse is 0.34942605724157794
# in experiment 9 best c is 0.005
# in experiment 9 test rmse is 0.347537336568417
# in experiment 0 best c is 0.005
# in experiment 0 test rmse is 0.3896656513332798
# in experiment 1 best c is 0.005
# in experiment 1 test rmse is 0.3929968559555456
# in experiment 2 best c is 0.005
# in experiment 2 test rmse is 0.40084468242048804
# in experiment 3 best c is 0.005
# in experiment 3 test rmse is 0.38429366957939665
# in experiment 4 best c is 0.005
# in experiment 4 test rmse is 0.36197506604508256
# in experiment 5 best c is 0.005
# in experiment 5 test rmse is 0.38976839420131515
# in experiment 6 best c is 0.005
# in experiment 6 test rmse is 0.4132805777921088
# in experiment 7 best c is 0.005
# in experiment 7 test rmse is 0.3410343257334908
# in experiment 8 best c is 0.005
# in experiment 8 test rmse is 0.3886004213057573
# in experiment 9 best c is 0.005
# in experiment 9 test rmse is 0.4052360505557913
# in experiment 0 best c is 0.005
# in experiment 0 test rmse is 0.30743745343999457
# in experiment 1 best c is 100
# in experiment 1 test rmse is 0.33713945886488655
# in experiment 2 best c is 0.005
# in experiment 2 test rmse is 0.3292294005827932
# in experiment 3 best c is 0.01
# in experiment 3 test rmse is 0.3098147183153833
# in experiment 4 best c is 0.005
# in experiment 4 test rmse is 0.33783240979532325
# in experiment 5 best c is 0.005
# in experiment 5 test rmse is 0.31744474997852484
# in experiment 6 best c is 0.05
# in experiment 6 test rmse is 0.3325565499310752
# in experiment 7 best c is 0.01
# in experiment 7 test rmse is 0.31260326595154914
# in experiment 8 best c is 0.005
# in experiment 8 test rmse is 0.3216411217046571
# in experiment 9 best c is 0.005
# in experiment 9 test rmse is 0.32271550326162485
# in experiment 0 best c is 0.05
# in experiment 0 test rmse is 0.3079916279820231
# in experiment 1 best c is 0.005
# in experiment 1 test rmse is 0.3078874599364837
# in experiment 2 best c is 0.03
# in experiment 2 test rmse is 0.2972195534207307
# in experiment 3 best c is 0.03
# in experiment 3 test rmse is 0.33641966928324685
# in experiment 4 best c is 0.005
# in experiment 4 test rmse is 0.2562975617703427
# in experiment 5 best c is 0.005
# in experiment 5 test rmse is 0.3140485399679125
# in experiment 6 best c is 0.03
# in experiment 6 test rmse is 0.2952870887456995
# in experiment 7 best c is 0.005
# in experiment 7 test rmse is 0.2855148786973332
# in experiment 8 best c is 0.03
# in experiment 8 test rmse is 0.3101706410557592
# in experiment 9 best c is 0.005
# in experiment 9 test rmse is 0.3262651804596774

# %%
import pandas as pd

rmse_test = []
for i in range(len(mean_scores)):
    rmse_test.append(str(round(mean_scores[i],5)) + " +/- " + str(2*round(std_scores[i],3)))

d = {'RMSE' : rmse_test}
df = pd.DataFrame(d, index = ['LinearFuzzifier','ExponentialFuzzifier','CrispFuzzifier', 'QuantileConstantPiecewiseFuzzifier', 'QuantileLinearPiecewiseFuzzifier'])
df.head()
# Out:
#                                                  RMSE
# LinearFuzzifier                           nan +/- nan
# ExponentialFuzzifier                0.32976 +/- 0.044
# CrispFuzzifier                       0.38677 +/- 0.04
# QuantileConstantPiecewiseFuzzifier  0.32284 +/- 0.022
# QuantileLinearPiecewiseFuzzifier    0.30371 +/- 0.042
