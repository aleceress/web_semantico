# %%
pwd
# Out:
# 'D:\\web_semantico'

# %%
import pytumblr
client = pytumblr.TumblrRestClient(
  '0Vmag12IU7cQcAoCxv4SfmZHMtTg9Kthi64SJrGsOQldgM09pF',
  'q0mff93zXfajkGTHU8iCmiHyPGXFmshRB0hvPqWx4zAJp1MAf3',
  'EWuEthX3VBYAN8uX21eiKTCkpmLUN3xt9hqOwgc7Lq42BMScrM',
  '5NfocByIHSZE9B599im2wXJcIGHDvR8ESByJiRYvIMAypdj3ND'
)

# %%
client.posts('melodrammaspiccio', type = 'text')
# Out:
# {'blog': {'admin': True,
#   'ask': True,
#   'ask_anon': False,
#   'ask_page_title': 'Ask me anything',
#   'asks_allow_media': True,
#   'avatar': [{'width': 512,
#     'height': 512,
#     'url': 'https://64.media.tumblr.com/0a0dac89bb4e1a6ebe373f7a93b92b45/5b88539ef9a00eff-37/s512x512u_c1/f7e798eee2e82840c78ab6ec15b7ab06fb053cbe.jpg'},
#    {'width': 128,
#     'height': 128,
#     'url': 'https://64.media.tumblr.com/0a0dac89bb4e1a6ebe373f7a93b92b45/5b88539ef9a00eff-37/s128x128u_c1/277201c008b6dbd5d992e9480b9c154e1598fb4b.jpg'},
#    {'width': 96,
#     'height': 96,
#     'url': 'https://64.media.tumblr.com/0a0dac89bb4e1a6ebe373f7a93b92b45/5b88539ef9a00eff-37/s96x96u_c1/c12679bea8a943fc3d0e59f695f81e4b400890bc.jpg'},
#    {'width': 64,
#     'height': 64,
#     'url': 'https://64.media.tumblr.com/0a0dac89bb4e1a6ebe373f7a93b92b45/5b88539ef9a00eff-37/s64x64u_c1/2251a0028ebfb64cced58d07e7a54b2586bea2bf.jpg'}],
#   'can_chat': True,
#   'can_send_fan_mail': True,
# ...

# %%
drafts = client.drafts('melodrammaspiccio')
print(drafts)
# Out:
# {'posts': [{'type': 'text', 'blog_name': 'melodrammaspiccio', 'blog': {'name': 'melodrammaspiccio', 'title': '', 'description': '<p>co(l)azione a ripetere </p>', 'url': 'https://melodrammaspiccio.tumblr.com/', 'uuid': 't:FNsrn1edDOvij468xJUAEQ', 'updated': 1627148116}, 'id': 657946553335562241, 'id_string': '657946553335562241', 'post_url': 'https://melodrammaspiccio.tumblr.com/post/657946553335562241/perch%C3%A9-ho-un-istintivo-fastidio-verso-le-emozioni', 'slug': 'perché-ho-un-istintivo-fastidio-verso-le-emozioni', 'date': '2021-07-28 10:05:29 GMT', 'timestamp': 1627466729, 'state': 'draft', 'format': 'html', 'reblog_key': 'yfVtqmDX', 'tags': [], 'short_url': 'https://tmblr.co/ZInwWqaXVkU0ma01', 'summary': 'Perché ho un istintivo fastidio verso le emozioni forti provate da persone di scarsa cultura?', 'should_open_in_legacy': False, 'recommended_source': None, 'recommended_color': None, 'followed': False, 'liked': False, 'note_count': 0, 'title': '', 'body': '<p>Perché ho un istint
# ...

# %%
for d in drafts:
    print(type(d))
# Out:
# <class 'str'>
# <class 'str'>

# %%
drafts_bodies
# Out:
# ['p', '_']

# %%
posts = drafts.posts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-99c738dc34ae> in <module>
# ----> 1 posts = drafts.posts
#
# AttributeError: 'dict' object has no attribute 'posts'
