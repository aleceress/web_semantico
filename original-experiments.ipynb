# %%
from mulearn import FuzzyInductor
from mulearn.kernel import PrecomputedKernel
from mulearn.fuzzifier import *
from mulearn.optimization import GurobiSolver
import csv
import numpy as np
from sklearn.model_selection import KFold, RandomizedSearchCV, GridSearchCV
import random
from sklearn.metrics import mean_squared_error

def get_kernel_and_solver(gram):
    eigvals = np.linalg.eigvals(gram)
    assert(sum([abs(e.imag) for e in eigvals]) < 1e-4)
    abs_neg_eigvals = [-l.real for l in eigvals if l < 0]
    adjustment = max(abs_neg_eigvals) if abs_neg_eigvals else 0

    kernel = PrecomputedKernel(gram)
    solver = GurobiSolver(adjustment=adjustment) if adjustment else GurobiSolver()
    return kernel, solver

def get_dataset(filename):
    with open(filename) as data_file:
        data = np.array(list(csv.reader(data_file)))

    n = len(data) - 1

    # ## Extract data names, membership values and Gram matrix

    names = np.array(data[0])[1:n+1]
    mu = np.array([float(row[0]) for row in data[1:n+1]])
    gram = np.array([[float(k.replace('NA', '0')) for k in row[1:n+1]]
                     for row in data[1:n+1]])

    assert(len(names.shape) == 1)
    assert(len(mu.shape) == 1)
    assert(len(gram.shape) == 2)

    assert(names.shape[0] == gram.shape[0] == gram.shape[1] == mu.shape[0])

    X = np.arange(n)

    return X, gram, mu

data_file_name = 'data/data-tettamanzi-complete.csv'
X, gram, mu = get_dataset(data_file_name)
k,s = get_kernel_and_solver(gram)

cs = [0.005, 0.007, 0.01, 0.03, 0.05, 0.07, 0.1, 0.3, 0.5,0.7, 1, 10, 100]

fuzzifiers = [LinearFuzzifier(), ExponentialFuzzifier(), CrispFuzzifier(), QuantileConstantPiecewiseFuzzifier(), QuantileLinearPiecewiseFuzzifier()]
mean_scores = []
std_scores = []

for fuzzifier in fuzzifiers:
    test_scores = []

    for i in range(10):
        random.shuffle(X)

        X_train = X[:1154]
        X_train = np.array([[x] for x in X_train])
        mu_train = []

        for x in X_train:
            mu_train.append(mu[x[0]])

        X_ms = X[1154:1299]
        X_ms = np.array([[x] for x in X_ms])
        mu_ms = []

        for x in X_ms:
            mu_ms.append(mu[x[0]])

        X_test = X[1299:]
        X_test = np.array([[x] for x in X_test])
        mu_test = []

        for x in X_test:
            mu_test.append(mu[x[0]])
        
        rmse_min = 1
        
        for c in cs:
            try:
                fi = FuzzyInductor(c = c, fuzzifier = fuzzifier, k = k, solver = s)
                fi.fit(X_train,mu_train)
                predictions = fi.predict(X_ms)
                rmse = mean_squared_error(predictions, mu_ms, squared=False)
                if  rmse < rmse_min:
                    best_param = c
                    rmse_min = rmse
            except ValueError as e:
                print(e)
                continue
                  
        print("in experiment " + str(i) + " best c is " + str(best_param))
        
        try:
            predictions = fi.predict(X_test)
            rmse = mean_squared_error(predictions, mu_test, squared=False)
            print(rmse)
            test_scores.append(rmse)
        except:
            test_scores.append(np.nan)

    mean_scores.append(np.nanmean(test_scores))
    std_scores.append(np.nanstd(test_scores))
# Out:
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 0 best c is 0.005
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 1 best c is 0.005
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 2 best c is 0.005
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 3 best c is 0.005
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 4 best c is 0.005
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 5 best c is 0.005
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 6 best c is 0.005
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 7 best c is 0.005
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 8 best c is 0.005
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# Profile fitting returned a negative parameter
# in experiment 9 best c is 0.005
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:106: RuntimeWarning: Mean of empty slice
# D:\anaconda\lib\site-packages\numpy\lib\nanfunctions.py:1666: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 0 best c is 0.07
# 0.3824446076137121
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 1 best c is 0.07
# 0.36799713051190586
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 2 best c is 0.3
# 0.40979663052284687
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 3 best c is 0.3
# 0.38383730751889633
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 4 best c is 0.5
# 0.3834702390165113
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 5 best c is 0.07
# 0.3862586968735705
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 6 best c is 0.07
# 0.3594501928157355
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 7 best c is 0.3
# 0.3846482299734022
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 8 best c is 0.05
# 0.3740737234684421
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# in experiment 9 best c is 0.07
# 0.3712786926920115
# in experiment 0 best c is 0.005
# 0.47468075174341207
# in experiment 1 best c is 0.005
# 0.4033661771860031
# in experiment 2 best c is 0.005
# 0.41396556831517467
# in experiment 3 best c is 0.005
# 0.4241028933750935
# in experiment 4 best c is 0.005
# 0.539353595245191
# in experiment 5 best c is 0.005
# 0.43126644186247887
# in experiment 6 best c is 0.005
# 0.47740665281870065
# in experiment 7 best c is 0.007
# 0.4071041959618876
# in experiment 8 best c is 0.005
# 0.48111025262355667
# in experiment 9 best c is 0.005
# 0.5173216469994695
# in experiment 0 best c is 0.07
# 0.2974803424453649
# in experiment 1 best c is 0.005
# 0.34944527642407297
# in experiment 2 best c is 0.07
# 0.3357233864597642
# in experiment 3 best c is 0.005
# 0.3374040759901772
# in experiment 4 best c is 0.005
# 0.3383494025527419
# in experiment 5 best c is 0.005
# 0.3508626005444084
# in experiment 6 best c is 0.03
# 0.3252405517494585
# in experiment 7 best c is 0.005
# 0.32441927555026007
# in experiment 8 best c is 0.01
# 0.3279057640595445
# in experiment 9 best c is 0.03
# 0.33288171910229536
# in experiment 0 best c is 0.005
# 0.30232652342928895
# in experiment 1 best c is 0.03
# 0.29747001665695977
# in experiment 2 best c is 0.05
# 0.32776477788810116
# in experiment 3 best c is 0.005
# 0.3064706418715661
# in experiment 4 best c is 0.05
# 0.3138458164076518
# in experiment 5 best c is 0.005
# 0.2822431468002047
# in experiment 6 best c is 0.5
# 0.3069910405729021
# in experiment 7 best c is 0.005
# 0.2809822921058935
# in experiment 8 best c is 0.005
# 0.2668689749654739
# in experiment 9 best c is 0.03
# 0.29891602576916204

# %%
import pandas as pd

rmse_test = []
for i in range(len(mean_scores)):
    rmse_test.append(str(round(mean_scores[i],5)) + " +/- " + str(2*round(std_scores[i],3)))

d = {'RMSE' : rmse_test}
df = pd.DataFrame(d, index = ['LinearFuzzifier','ExponentialFuzzifier','CrispFuzzifier', 'QuantileConstantPiecewiseFuzzifier', 'QuantileLinearPiecewiseFuzzifier'])
df.head()
# Out:
#                                                  RMSE
# LinearFuzzifier                           nan +/- nan
# ExponentialFuzzifier                0.38033 +/- 0.026
# CrispFuzzifier                       0.45697 +/- 0.09
# QuantileConstantPiecewiseFuzzifier  0.33197 +/- 0.028
# QuantileLinearPiecewiseFuzzifier    0.29839 +/- 0.034
